# %% [markdown]
# # 02 Unsupervised

# %%
import pandas as pd
from pathlib import Path
ROOT=Path('..').resolve()
pd.read_csv(ROOT/'reports/tables/unsupervised_metrics_subset.csv').head(24)
# Out:
#          ari       nmi  silhouette  n_clusters                embedding  \
# 0   0.294857  0.387791    0.829591          21                     tsne
# 1   0.294761  0.416867    0.775815          16            umap_fallback
# 2   0.239466  0.346976    0.714908          11          pacmap_fallback
# 3   0.078831  0.197357    0.647950           9              autoencoder
# 4   0.052089  0.209973    0.695138          11                      pca
# 5   0.043990  0.183483    0.545311           9          trimap_fallback
# 6  -0.006325  0.078271    0.595682           7                     dpca
# 7  -0.011645  0.049702    0.573016           2                     mpca
# 8   0.218196  0.379006    0.674979          16                     tsne
# 9   0.132469  0.378468    0.503863          16          pacmap_fallback
# 10  0.106126  0.332245    0.620748          16            umap_fallback
# 11  0.066726  0.345954    0.554388          16          trimap_fallback
# ...
