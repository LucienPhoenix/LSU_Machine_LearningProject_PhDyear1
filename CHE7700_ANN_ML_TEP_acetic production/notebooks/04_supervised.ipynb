# %% [markdown]
# # 04 Supervised

# %%
import pandas as pd
from pathlib import Path
ROOT=Path('..').resolve()
pd.read_csv(ROOT/'reports/tables/supervised_metrics.csv')
# Out:
#                model  accuracy        f1   roc_auc
# 0      Random Forest  0.934014  0.965881  0.846461
# 1  Gradient Boosting  0.934014  0.965881  0.845342
# 2               LSTM  0.933333  0.965517  0.822615
