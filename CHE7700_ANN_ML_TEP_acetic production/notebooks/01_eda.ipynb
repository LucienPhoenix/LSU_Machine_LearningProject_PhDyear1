# %% [markdown]
# # 01. EDA (Exploratory Data Analysis)
# # Load and inspect the combined TEP dataset.

# %%
import pandas as pd
from pathlib import Path
ROOT=Path('..').resolve()
pd.read_csv(ROOT/'reports/tables/dataset_summary.csv')
df.head()
# Out:
#                 metric  value
# 0              n_files     16
# 1  common_sensor_count     50
# 2           total_rows   7286
# 3           train_rows   5816
# 4            test_rows   1470

# %%
df.describe().T.head(15)
# Out:
#        count    mean          std   min    25%     50%     75%     max
# value    7.0  3132.0  3340.377374  16.0  265.5  1470.0  6310.5  7286.0
